// %% [markdown]
// # Lab 8 Exercise 4
//
// ## Fields declaration and initialization

// %% [markdown]
// 1. สร้าง console application project
//
// ```
//     dotnet new console --name Lab08_Ex04
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >  1. var myObj = new MyClass();
// >  2.
// >  3. System.Console.WriteLine($"Default integer      F1 = {myObj.F1}");  //Implicit fields initialization
// >  4. System.Console.WriteLine($"Default string       F2 = {myObj.F2}");
// >  5. System.Console.WriteLine($"Initialized integer  F3 = {myObj.F3}");  //Explicit field initialization
// >  6. System.Console.WriteLine($"Initialized string   F4 = {myObj.F4}");
// >  7.
// >  8. class MyClass
// >  9. {
// > 10.    public int F1;
// > 11.    public string F2;
// > 12.    public int F3 = 100;
// > 13.    public string F4 = "ASDF";
// > 14. }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
//     dotnet build  Lab08_Ex04
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
//     dotnet run --project Lab08_Ex04
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Implicit initialization คือการตั้งค่าฟิลด์โดยอัตโนมัติเมื่อไม่กำหนดค่าเริ่มต้นในระหว่างการประกาศ โดย C# จะตั้งค่าฟิลด์ที่เป็นประเภทพื้นฐาน เช่น int, bool ให้เป็นค่าเริ่มต้นที่กำหนดไว้ (เช่น 0 สำหรับ int, false สำหรับ bool) และ string ให้เป็น null

// %% [markdown]
// 8. นำ code ในข้อ 2 มารันบน polyglot notebook  โดยใส่ใน  code cell ด้านล่างนี้

// %%
// พื้นที่เขียน code ตามข้อ 
var myObj = new MyClass();

System.Console.WriteLine($"Default integer      F1 = {myObj.F1}");  //Implicit fields initialization
System.Console.WriteLine($"Default string       F2 = {myObj.F2}");
System.Console.WriteLine($"Initialized integer  F3 = {myObj.F3}");  //Explicit field initialization
System.Console.WriteLine($"Initialized string   F4 = {myObj.F4}");

class MyClass
{
    public int F1;
    public string F2;
    public int F3 = 100;
    public string F4 = "ASDF";
}

// %% [markdown]
// 8.1 ผลการรันเป็นอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Default integer      F1 = 0
//
// Default string       F2 =
//
// Initialized integer  F3 = 100
//
// Initialized string   F4 = ASDF

// %% [markdown]
// 8.2 เหมือนหรือต่างจาก console application อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เหมือนกัน

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Field ในภาษา C# คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ตัวแปรที่ประกาศภายในคลาสหรือโครงสร้าง (class หรือ struct) ซึ่งใช้เก็บข้อมูลหรือสถานะของอ็อบเจ็กต์ที่สร้างจากคลาสนั้นๆ

// %% [markdown]
// 2. Field มีหน้าที่อะไรใน class

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// มีหน้าที่หลักในการเก็บข้อมูลหรือสถานะ (state) ของอ็อบเจ็กต์ที่ถูกสร้างจากคลาสนั้นๆ

// %% [markdown]
// 3. การประกาศ Field ทำได้อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ทำได้โดยการกำหนดตัวแปรไว้ภายในคลาสหรือ struct โดยตรง พร้อมกับระบุประเภทข้อมูลและ Access Modifier (เช่น public, private, protected หรือ internal)

// %% [markdown]
// 4. Implicit fields initialization  คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การที่ฟิลด์ได้รับค่าพื้นฐานจาก C# โดยอัตโนมัติหากไม่ได้กำหนดค่าเริ่มต้นไว้

// %% [markdown]
// 5. Explicit field initialization คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การกำหนดค่าตั้งต้น (initial value) ให้กับฟิลด์ (field) โดยตรงเมื่อทำการประกาศฟิลด์ในคลาส หรือโครงสร้าง (struct)

// %% [markdown]
// 6. Implicit fields initialization  และ Explicit field initialization แตกต่างกันอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Implicit Initialization เป็นการที่ C# กำหนดค่าเริ่มต้นโดยอัตโนมัติให้กับฟิลด์ตามชนิดข้อมูลของฟิลด์นั้นๆ
//
// Explicit Initialization เป็นการที่ผู้พัฒนากำหนดค่าเริ่มต้นที่ชัดเจนให้กับฟิลด์เมื่อประกาศฟิลด์นั้นๆ
