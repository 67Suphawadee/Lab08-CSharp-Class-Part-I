// %% [markdown]
// # Lab 8 Exercise 3
//
// ## การควบคุมการเข้าถึงสมาชิกในคลาส (fields)

// %% [markdown]
// 1. สร้าง console application project
//
// > ```
// >     dotnet new console --name Lab08_Ex03
// > ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >  1. Person p = new Person();
// >  2. p.name = "Rambo";
// >  3. p.id = "1987";
// >  4. p.income = 2500;
// >  5. System.Console.WriteLine($"Type of p is {p.GetType()}");
// >  6. System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
// >  7. System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
// >  8. System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");
// >  9.
// > 10. class Person
// > 11. {
// > 12.     public string? name;
// > 13.     public string? id;
// > 14.     public int income;
// > 15. }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// > ```
// >     dotnet build  Lab08_Ex03
// > ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// > ```
// >     dotnet run --project Lab08_Ex03
// > ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. นำโค้ดในข้อ 2  มารันใน code cell

// %%
// code cell สำหรับทดสอบโปรแกรมในข้อ 2 บน polyglot
Person p = new Person();
p.name = "Rambo";
p.id = "1987";
p.income = 2500;
System.Console.WriteLine($"Type of p is {p.GetType()}");
System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");

class Person
{
    public string? name;
    public string? id;
    public int income;
}

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Access modifier ในภาษา C# คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การกำหนดระดับการเข้าถึงของสมาชิกในคลาส (เช่น ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้)

// %% [markdown]
// 2. จงอธิบายขอบเขตและการใช้งานของ Access modifier ต่อไปนี้

// %% [markdown]
// 2.1  public

// %% [markdown]
// *คำตอบ*

// %% [markdown]
//  เป็น Access Modifier ที่ใช้สำหรับกำหนดให้สมาชิกของคลาส (เช่น ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้) สามารถเข้าถึงได้จาก ทุกที่ โดยไม่จำกัด ไม่ว่าจะเป็นภายในคลาสเดียวกัน, คลาสที่สืบทอด, หรือจากภายนอกคลาสนั้น ๆ หรือโปรเจ็กต์

// %% [markdown]
// 2.2 private

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เป็น Access Modifier ที่ใช้เพื่อจำกัดการเข้าถึงสมาชิกของคลาส (เช่น ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้) ให้อยู่ภายในคลาสนั้น ๆ เท่านั้น ซึ่งหมายความว่า สมาชิกที่ประกาศเป็น private จะไม่สามารถเข้าถึงได้จากภายนอกคลาสนั้น ไม่ว่าจะเป็นคลาสอื่น, คลาสที่สืบทอด, หรือจากโปรเจ็กต์ภายนอก

// %% [markdown]
// 2.3 protected

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เป็น Access Modifier ที่ใช้เพื่อกำหนดระดับการเข้าถึงของสมาชิก (ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้) ให้สามารถเข้าถึงได้จาก ภายในคลาสที่ประกาศสมาชิกนั้น และ คลาสที่สืบทอด (subclasses) จากคลาสนั้นเท่านั้น แต่ไม่สามารถเข้าถึงได้จากภายนอกคลาสหรือจากคลาสที่ไม่เกี่ยวข้อง

// %% [markdown]
// 2.4 internal

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เป็น Access Modifier ที่ใช้เพื่อกำหนดการเข้าถึงสมาชิก (ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้) ให้สามารถเข้าถึงได้ ภายในแอปพลิเคชันหรือโปรเจ็กต์เดียวกัน เท่านั้น แต่จะไม่สามารถเข้าถึงได้จากโปรเจ็กต์หรือแอปพลิเคชันภายนอก ถึงแม้จะอยู่ในคลาสเดียวกันก็ตามหากไม่อยู่ในโปรเจ็กต์เดียวกัน

// %% [markdown]
// 2.5 protected internal

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เป็น Access Modifier ที่เป็นการผสมผสานระหว่าง protected และ internal โดยให้สมาชิก (ฟิลด์, เมธอด, หรือพร็อพเพอร์ตี้) สามารถเข้าถึงได้

// %% [markdown]
// 3. ถ้าแก้ไขโค้ดในบรรทัดที่ 14 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร
// ```csharp
//     private int income;
// ```

// %%
// พื้นที่เขียน code และทดสอบ
Person p = new Person();
p.name = "Rambo";
p.id = "1987";
p.income = 2500;
System.Console.WriteLine($"Type of p is {p.GetType()}");
System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");

class Person
{
    public string? name;
    public string? id;
    private int income;
}

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ไม่สามารถรันได้

// %% [markdown]
// 4. ถ้าแก้ไขโค้ดในบรรทัดที่ 13 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร
// ```csharp
//     protected string? name;
// ```

// %%
// พื้นที่เขียน code และทดสอบ
Person p = new Person();
p.name = "Rambo";
p.id = "1987";
p.income = 2500;
System.Console.WriteLine($"Type of p is {p.GetType()}");
System.Console.WriteLine($"p.name = {p.name}\ttype = {p.name.GetType()}");
System.Console.WriteLine($"p.id = {p.id}\ttype = {p.id.GetType()}");
System.Console.WriteLine($"p.income = {p.income}\ttype = {p.income.GetType()}");

class Person
{
    public string? name;
    protected string? name;
    public int income;
}

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// รันไม่ได้

// %% [markdown]
// 3. เครื่องหมาย `?` ในบรรทัดที่ 13 `protected string? name;` มีความหมายว่าอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เครื่องหมาย ? ที่ใช้ใน string? หมายถึงการทำให้ตัวแปรสามารถเก็บค่า null ได้ ซึ่งมีประโยชน์ในกรณีที่คาดว่าอาจจะไม่มีค่า (เช่น เมื่อข้อมูลยังไม่ได้รับการกำหนดค่า)
